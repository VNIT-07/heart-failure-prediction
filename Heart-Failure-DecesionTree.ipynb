# %%
import pandas as pd

# %%
df = pd.read_csv('heart_failure_clinical_records_dataset.csv')

# %%
x = df.iloc[:,:-1].values
y = df.iloc[:,-1].values

# %%
from sklearn.model_selection import train_test_split
xTrain, xTest, yTrain, yTest = train_test_split(x,y,test_size=0.33,random_state=0)

# %%
from sklearn.tree import DecisionTreeClassifier
model = DecisionTreeClassifier(random_state=100,max_depth=5,min_samples_split=10,min_samples_leaf=5,criterion='entropy')
model.fit(xTrain,yTrain)
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=5, min_samples_leaf=5,
#                        min_samples_split=10, random_state=100)

# %%
yPred = model.predict(xTest)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

importances = model.feature_importances_
features = df.columns[:-1]
plt.figure(figsize=(10, 6))
sns.barplot(x=importances, y=features)
plt.title('Feature Importance in Random Forest')
plt.ylabel('Features')
plt.xlabel("Importance")
plt.show()

# %%
from sklearn.metrics import accuracy_score, classification_report, r2_score
print("----------- Classification_report -----------")
print(classification_report(yTest,yPred))
print("----------- accuracy_score -----------")
print("accuracy_score: ",round(accuracy_score(yTest,yPred)*100,2))
print("----------- r2_score -----------")
print("r2_score: ",r2_score(yTest,yPred))
# Out:
# ----------- Classification_report -----------
#               precision    recall  f1-score   support
#
#            0       0.87      0.97      0.92        67
#            1       0.92      0.69      0.79        32
#
#     accuracy                           0.88        99
#    macro avg       0.89      0.83      0.85        99
# weighted avg       0.88      0.88      0.87        99
#
# ----------- accuracy_score -----------
# accuracy_score:  87.88
# ----------- r2_score -----------
# r2_score:  0.4458955223880595
